# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Dataset/iris/iris.data')

# %% [markdown]
# ##### Data Visualization

# %%
#check how many we have of each species and data types
df["variety"].value_counts()
# Out:
# Setosa        50
# Versicolor    50
# Virginica     50
# Name: variety, dtype: int64

# %% [markdown]
# #### Data visualization
#
# ###### idea is to see could we minize the number of the inputs(features) which we would use in our multilayer perceptron either to make it more simple or to try to increase performance
#
# 1. try to understand correlation between features
#      * positive
#      * negative
#      * no correlation
#
# 2. kernel density estimation
#     * to understand frequency distribution

# %%
#Pearson Correlation Coefficient 
df.corr()
# Out:
#               sepal.length  sepal.width  petal.length  petal.width
# sepal.length      1.000000    -0.117570      0.871754     0.817941
# sepal.width      -0.117570     1.000000     -0.428440    -0.366126
# petal.length      0.871754    -0.428440      1.000000     0.962865
# petal.width       0.817941    -0.366126      0.962865     1.000000

# %%
#examine relationships between data
sns.pairplot(df, hue=df.columns[len(df.columns)-1], palette="husl", height=3, diag_kind="kde")

# %%
#create generic function for kernel den est which assumtion that the last column is label
def kern_dens_est(data):
    for i in range(len(data.columns)-1):
        sns.FacetGrid(df, hue=data.columns[len(df.columns)-1], palette="husl", height=6).map(sns.kdeplot, data.columns[i]) \
   .add_legend()

# %%
kern_dens_est(df)
len(df.columns)
print(df.columns[4])
print(df.columns[len(df.columns)-1])
# Out:
# variety
# variety
